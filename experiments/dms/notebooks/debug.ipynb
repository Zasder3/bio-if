# %%
from transformers import AutoModelForMaskedLM

# %%
model = AutoModelForMaskedLM.from_pretrained("facebook/esm2_t36_3B_UR50D", device_map=f'cuda:0')
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
for name, param in model.named_parameters():
    print(name, param.size())
# Out:
# esm.embeddings.word_embeddings.weight torch.Size([33, 2560])
# esm.embeddings.position_embeddings.weight torch.Size([1026, 2560])
# esm.encoder.layer.0.attention.self.query.weight torch.Size([2560, 2560])
# esm.encoder.layer.0.attention.self.query.bias torch.Size([2560])
# esm.encoder.layer.0.attention.self.key.weight torch.Size([2560, 2560])
# esm.encoder.layer.0.attention.self.key.bias torch.Size([2560])
# esm.encoder.layer.0.attention.self.value.weight torch.Size([2560, 2560])
# esm.encoder.layer.0.attention.self.value.bias torch.Size([2560])
# esm.encoder.layer.0.attention.output.dense.weight torch.Size([2560, 2560])
# esm.encoder.layer.0.attention.output.dense.bias torch.Size([2560])
# esm.encoder.layer.0.attention.LayerNorm.weight torch.Size([2560])
# esm.encoder.layer.0.attention.LayerNorm.bias torch.Size([2560])
# esm.encoder.layer.0.intermediate.dense.weight torch.Size([10240, 2560])
# esm.encoder.layer.0.intermediate.dense.bias torch.Size([10240])
# ...

# %%
str(model.esm.encoder.layer[0].intermediate.dense)
# Out:
# 'Linear(in_features=2560, out_features=10240, bias=True)'

# %%
type(model)
# Out:
# transformers.models.esm.modeling_esm.EsmForMaskedLM
